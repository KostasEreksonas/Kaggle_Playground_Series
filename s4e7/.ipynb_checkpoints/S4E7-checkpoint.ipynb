# %%
import pandas as pd

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
submission = pd.read_csv('data/sample_submission.csv')

# %%
train = train.drop("id", axis=1)
test = test.drop("id", axis=1)

# %%
train.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0    Male   21                1         35.0                   0    1-2 Year
# 1    Male   43                1         28.0                   0   > 2 Years
# 2  Female   25                1         14.0                   1    < 1 Year
# 3  Female   35                1          1.0                   0    1-2 Year
# 4  Female   36                1         15.0                   1    1-2 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         65101.0                 124.0      187         0
# 1            Yes         58911.0                  26.0      288         1
# 2             No         38043.0                 152.0      254         0
# 3            Yes          2630.0                 156.0       76         0
# 4             No         31951.0                 152.0      294         0

# %%
test.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0  Female   20                1         47.0                   0    < 1 Year
# 1    Male   47                1         28.0                   0    1-2 Year
# 2    Male   47                1         43.0                   0    1-2 Year
# 3  Female   22                1         47.0                   1    < 1 Year
# 4    Male   51                1         19.0                   0    1-2 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0             No          2630.0                 160.0      228
# 1            Yes         37483.0                 124.0      123
# 2            Yes          2630.0                  26.0      271
# 3             No         24502.0                 152.0      115
# 4             No         34115.0                 124.0      148

# %%
submission.head()
# Out:
#          id  Response
# 0  11504798       0.5
# 1  11504799       0.5
# 2  11504800       0.5
# 3  11504801       0.5
# 4  11504802       0.5

# %%
train.describe()
# Out:
#                 Age  Driving_License   Region_Code  Previously_Insured  \
# count  1.150480e+07     1.150480e+07  1.150480e+07        1.150480e+07
# mean   3.838356e+01     9.980220e-01  2.641869e+01        4.629966e-01
# std    1.499346e+01     4.443120e-02  1.299159e+01        4.986289e-01
# min    2.000000e+01     0.000000e+00  0.000000e+00        0.000000e+00
# 25%    2.400000e+01     1.000000e+00  1.500000e+01        0.000000e+00
# 50%    3.600000e+01     1.000000e+00  2.800000e+01        0.000000e+00
# 75%    4.900000e+01     1.000000e+00  3.500000e+01        1.000000e+00
# max    8.500000e+01     1.000000e+00  5.200000e+01        1.000000e+00
#
#        Annual_Premium  Policy_Sales_Channel       Vintage      Response
# count    1.150480e+07          1.150480e+07  1.150480e+07  1.150480e+07
# mean     3.046137e+04          1.124254e+02  1.638977e+02  1.229973e-01
# std      1.645475e+04          5.403571e+01  7.997953e+01  3.284341e-01
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11504798 entries, 0 to 11504797
# Data columns (total 11 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Gender                object
#  1   Age                   int64
#  2   Driving_License       int64
#  3   Region_Code           float64
#  4   Previously_Insured    int64
#  5   Vehicle_Age           object
#  6   Vehicle_Damage        object
#  7   Annual_Premium        float64
#  8   Policy_Sales_Channel  float64
#  9   Vintage               int64
#  10  Response              int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 965.5+ MB

# %%
test.describe()
# Out:
#                 Age  Driving_License   Region_Code  Previously_Insured  \
# count  7.669866e+06     7.669866e+06  7.669866e+06        7.669866e+06
# mean   3.839137e+01     9.980208e-01  2.642661e+01        4.630772e-01
# std    1.499951e+01     4.444387e-02  1.299433e+01        4.986349e-01
# min    2.000000e+01     0.000000e+00  0.000000e+00        0.000000e+00
# 25%    2.400000e+01     1.000000e+00  1.500000e+01        0.000000e+00
# 50%    3.600000e+01     1.000000e+00  2.800000e+01        0.000000e+00
# 75%    4.900000e+01     1.000000e+00  3.500000e+01        1.000000e+00
# max    8.500000e+01     1.000000e+00  5.200000e+01        1.000000e+00
#
#        Annual_Premium  Policy_Sales_Channel       Vintage
# count    7.669866e+06          7.669866e+06  7.669866e+06
# mean     3.046553e+04          1.123650e+02  1.638996e+02
# std      1.644586e+04          5.407358e+01  7.998445e+01
# min      2.630000e+03          1.000000e+00  1.000000e+01
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7669866 entries, 0 to 7669865
# Data columns (total 10 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Gender                object
#  1   Age                   int64
#  2   Driving_License       int64
#  3   Region_Code           float64
#  4   Previously_Insured    int64
#  5   Vehicle_Age           object
#  6   Vehicle_Damage        object
#  7   Annual_Premium        float64
#  8   Policy_Sales_Channel  float64
#  9   Vintage               int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 585.2+ MB

# %%
train_null = train.isna().sum().sum()
print(f"Null values in train dataset: {train_null}")
# Out:
# Null values in train dataset: 0

# %%
test_null = test.isna().sum().sum()
print(f"Null values in test dataset: {test_null}")
# Out:
# Null values in test dataset: 0

# %%
train_duplicate = train.duplicated().any()
print(f"Duplicated data in train dataset: {train_duplicate}")
# Out:
# Duplicated data in train dataset: False

# %%
test_duplicate = test.duplicated().any()
print(f"Duplicated data in test dataset: {test_duplicate}")
# Out:
# Duplicated data in test dataset: False
